# %% [markdown]
# # Análisando Atributos Atlas 2013

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt
import numpy as np

# Importando
arquivo_excel = 'Atlas 2013_municipal, estadual e Brasil.xlsx'

#Planilhas do Excel
municipio = 'MUN 91-00-10'
UF = 'UF 91-00-10'
BR = 'BR 91-00-10'

#Dicionário 
df_siglas = pd.read_excel(arquivo_excel)

#DataFrame por Planilha
df_mun = pd.read_excel(arquivo_excel, sheet_name = municipio)
df_UF = pd.read_excel(arquivo_excel, sheet_name = UF)
df_BR = pd.read_excel(arquivo_excel, sheet_name = BR)

# %%
df_mun.describe()
# Out:
#                 ANO            UF        Codmun6       Codmun7       ESPVIDA  \
# count  16695.000000  16695.000000   16695.000000  1.669500e+04  16695.000000
# mean    2000.333333     32.372327  325304.894160  3.253053e+06     68.411614
# std        7.760530      9.829369   98446.250439  9.844625e+05      5.445469
# min     1991.000000     11.000000  110001.000000  1.100015e+06     50.970000
# 25%     1991.000000     25.000000  251210.000000  2.512101e+06     64.830000
# 50%     2000.000000     31.000000  314620.000000  3.146206e+06     69.190000
# 75%     2010.000000     41.000000  411900.000000  4.119004e+06     72.650000
# max     2010.000000     53.000000  530010.000000  5.300108e+06     78.640000
#
#              FECTOT         MORT1         MORT5        RAZDEP       SOBRE40  \
# count  16695.000000  16695.000000  16695.000000  16695.000000  16695.000000
# mean       2.929683     33.267208     40.237872     62.984688     89.783321
# ...

# %% [markdown]
# ## Atributos

# %%
pd.set_option('display.max_columns', None)
print(list(df_mun.columns))
# Out:
# ['ANO', 'UF', 'Codmun6', 'Codmun7', 'Município', 'ESPVIDA', 'FECTOT', 'MORT1', 'MORT5', 'RAZDEP', 'SOBRE40', 'SOBRE60', 'T_ENV', 'E_ANOSESTUDO', 'T_ANALF11A14', 'T_ANALF15A17', 'T_ANALF15M', 'T_ANALF18A24', 'T_ANALF18M', 'T_ANALF25A29', 'T_ANALF25M', 'T_ATRASO_0_BASICO', 'T_ATRASO_0_FUND', 'T_ATRASO_0_MED', 'T_ATRASO_1_BASICO', 'T_ATRASO_1_FUND', 'T_ATRASO_1_MED', 'T_ATRASO_2_BASICO', 'T_ATRASO_2_FUND', 'T_ATRASO_2_MED', 'T_FBBAS', 'T_FBFUND', 'T_FBMED', 'T_FBPRE', 'T_FBSUPER', 'T_FLBAS', 'T_FLFUND', 'T_FLMED', 'T_FLPRE', 'T_FLSUPER', 'T_FREQ0A3', 'T_FREQ11A14', 'T_FREQ15A17', 'T_FREQ18A24', 'T_FREQ25A29', 'T_FREQ4A5', 'T_FREQ4A6', 'T_FREQ5A6', 'T_FREQ6', 'T_FREQ6A14', 'T_FREQ6A17', 'T_FREQFUND1517', 'T_FREQFUND1824', 'T_FREQFUND45', 'T_FREQMED1824', 'T_FREQMED614', 'T_FREQSUPER1517', 'T_FUND11A13', 'T_FUND12A14', 'T_FUND15A17', 'T_FUND16A18', 'T_FUND18A24', 'T_FUND18M', 'T_FUND25M', 'T_MED18A20', 'T_MED18A24', 'T_MED18M', 'T_MED19A21', 'T_MED25M', 'T_SUPER25M', 'CORTE1', 'CORTE2', '
# ...

# %%
df_mun.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16695 entries, 0 to 16694
# Columns: 237 entries, ANO to IDHM_R
# dtypes: float64(167), int64(69), object(1)
# memory usage: 30.2+ MB

# %% [markdown]
# ## Ajustando Dicionario e Visualizando Adequadamente

# %%
df_siglas.drop('DEFINIÇÃO', axis=1, inplace=True)
df_siglas.drop('NOME LONGO', axis=1, inplace=True)
df_siglas.rename(columns={'NOME CURTO': 'NOME_CURTO'}, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 df_siglas.drop('DEFINIÇÃO', axis=1)
#       2 df_siglas.drop('NOME LONGO', axis=1)
#       3 df_siglas.rename(columns={'NOME CURTO': 'NOME_CURTO'}, inplace=True)
#
# File ~\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    print(df_siglas)
# Out:
#                      SIGLA                                         NOME_CURTO
# 0                       UF                     Código da Unidade da Federação
# 1                      UFN                       Nome da Unidade da Federação
# 2                  CODMUN6                                Código do Município
# 3                  CODMUN7                                Código do Município
# 4                  NOMEMUN                                  Nome do Município
# 5                  ESPVIDA                       Esperança de vida ao nascer
# 6                   FECTOT                          Taxa de fecundidade total
# 7                    MORT1                               Mortalidade infantil
# 8                    MORT5                    Mortalidade até 5 anos de idade
# 9                   RAZDEP                               Razão de dependência
# 10                 SOBRE40         Probabilidade de sobrevivência até 40 anos
# ...
