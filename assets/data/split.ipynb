# %%
import pandas as pd

# Lê o arquivo CSV com a codificação correta (pode ser 'latin1', 'iso-8859-1' ou outra)
df = pd.read_csv(r"C:\\Users\\claud\\OneDrive\\Área de Trabalho\\Iniciação Científica\\Chikunguya-CAPTO\\assets\\data\\ibge_cnv_sanmg143039177_182_62_236.csv", encoding='latin1', delimiter=';')

# %%
df.head()
# Out:
#                     Município  \
# 0  310010 ABADIA DOS DOURADOS
# 1               310020 ABAETE
# 2           310030 ABRE CAMPO
# 3              310040 ACAIACA
# 4              310050 ACUCENA
#
#   Rede geral de esgoto ou pluvial - não discriminado  \
# 0                                               1320
# 1                                               6087
# 2                                               1928
# 3                                                767
# 4                                               1189
#
#   Fossa séptica - não discriminada Fossa rudimentar - não discriminada  \
# 0                               94                                 770
# 1                              436                                1093
# 2                               51                                 168
# 3                               34                                 113
# 4                              180                                 251
#
# ...

# %%
# Separa 'Município' em duas novas colunas 'ID' e 'Municipio'
df[['ID', 'Municipio']] = df['Município'].str.split(" ", 1, expand=True)
# Out:
# C:\Users\claud\AppData\Local\Temp\ipykernel_33840\580439996.py:2: FutureWarning: In a future version of pandas all arguments of StringMethods.split except for the argument 'pat' will be keyword-only.
#   df[['ID', 'Municipio']] = df['Município'].str.split(" ", 1, expand=True)

# %%
df.head()
# Out:
#                     Município  \
# 0  310010 ABADIA DOS DOURADOS
# 1               310020 ABAETE
# 2           310030 ABRE CAMPO
# 3              310040 ACAIACA
# 4              310050 ACUCENA
#
#   Rede geral de esgoto ou pluvial - não discriminado  \
# 0                                               1320
# 1                                               6087
# 2                                               1928
# 3                                                767
# 4                                               1189
#
#   Fossa séptica - não discriminada Fossa rudimentar - não discriminada  \
# 0                               94                                 770
# 1                              436                                1093
# 2                               51                                 168
# 3                               34                                 113
# 4                              180                                 251
#
# ...

# %%
# Removendo a coluna "Município"
df.drop('Município', axis=1, inplace=True)

# %%
df.head()
# Out:
#   Rede geral de esgoto ou pluvial - não discriminado  \
# 0                                               1320
# 1                                               6087
# 2                                               1928
# 3                                                767
# 4                                               1189
#
#   Fossa séptica - não discriminada Fossa rudimentar - não discriminada  \
# 0                               94                                 770
# 1                              436                                1093
# 2                               51                                 168
# 3                               34                                 113
# 4                              180                                 251
#
#   Vala - não discriminada Rio, lago ou mar  \
# 0                      15               68
# 1                       8               17
# 2                      95             1513
# ...

# %%
# Salva o DataFrame em um arquivo CSV
df.to_csv(r'C:\Users\claud\OneDrive\Área de Trabalho\Iniciação Científica\Chikunguya-CAPTO\assets\data\ibge_cnv_sanmg.csv', index=False, encoding='utf-8')
